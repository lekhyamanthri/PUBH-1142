# %% [markdown]
# # **The Impact of Air Quality on Overall Health - Research Project**

# %% [markdown]
# #### *Package Import*

# %%
import pandas
import seaborn
import matplotlib
from matplotlib import pyplot

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
seaborn.set_style('whitegrid')

# %% [markdown]
# #### *Data Import*

# %%
import pandas as pd
#Load the dataset 
df = pd.read_csv('air_quality_data.csv')

# %% [markdown]
# #### *Summary Statistics*

# %%
df.columns
# Out:
# Index(['RecordID', 'AQI', 'PM10', 'PM2_5', 'NO2', 'SO2', 'O3', 'Temperature',
#        'Humidity', 'WindSpeed', 'RespiratoryCases', 'CardiovascularCases',
#        'HospitalAdmissions', 'HealthImpactScore', 'HealthImpactClass'],
#       dtype='object')

# %%
df.CardiovascularCases.describe()
# Out:
# count    5811.000000
# mean        4.988986
# std         2.216791
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         6.000000
# max        14.000000
# Name: CardiovascularCases, dtype: float64

# %%
df.Humidity.describe()
# Out:
# count    5811.000000
# mean       54.776853
# std        26.020786
# min        10.001506
# 25%        31.995262
# 50%        54.543904
# 75%        77.641639
# max        99.997493
# Name: Humidity, dtype: float64

# %%
df.Temperature.describe()
# Out:
# count    5811.000000
# mean       14.975500
# std        14.483067
# min        -9.990998
# 25%         2.481500
# 50%        14.942428
# 75%        27.465374
# max        39.963434
# Name: Temperature, dtype: float64

# %%
df.groupby('HospitalAdmissions')['Humidity'].describe()
# Out:
#                      count       mean        std        min        25%  \
# HospitalAdmissions
# 0                    772.0  55.056113  25.917727  10.130002  32.156278
# 1                   1552.0  54.349943  26.088629  10.055160  32.171766
# 2                   1615.0  55.966558  25.741514  10.182220  33.759090
# 3                   1041.0  53.595745  26.015180  10.001506  30.637813
# 4                    561.0  54.452005  26.161915  10.201643  32.478029
# 5                    179.0  53.672264  26.879067  10.008423  28.102050
# 6                     60.0  52.959762  28.728128  10.689187  26.744632
# 7                     28.0  62.185733  26.862393  17.253345  43.770987
# 8                      2.0  59.875241   7.070012  54.875988  57.375614
# 12                     1.0  81.251557        NaN  81.251557  81.251557
#
#                           50%        75%        max
# HospitalAdmissions
# 0                   54.427004  78.481612  99.919898
# 1                   53.773851  76.534868  99.984138
# 2                   56.114851  78.866517  99.924140
# 3                   53.452047  75.688226  99.997493
# 4                   53.526042  77.628882  99.806367
# 5                   51.940679  77.256321  99.672172
# 6                   55.103377  76.791409  99.677771
# 7                   61.485598  89.256161  99.057990
# 8                   59.875241  62.374868  64.874494
# 12                  81.251557  81.251557  81.251557

# %%
df.groupby('HospitalAdmissions')['Temperature'].describe()
# Out:
#                      count       mean        std        min        25%  \
# HospitalAdmissions
# 0                    772.0  14.482135  14.820935  -9.911402   1.783798
# 1                   1552.0  15.319790  14.162938  -9.990998   3.045229
# 2                   1615.0  14.680630  14.540219  -9.970262   2.101487
# 3                   1041.0  14.715736  14.434331  -9.967557   2.180013
# 4                    561.0  16.145191  14.657516  -9.931904   3.065179
# 5                    179.0  15.305114  14.733664  -9.830318   2.637572
# 6                     60.0  13.157105  15.206991  -9.542573  -0.193321
# 7                     28.0  13.755182  14.307690  -9.938031   5.625095
# 8                      2.0  29.554798   9.832802  22.601957  26.078378
# 12                     1.0   7.057267        NaN   7.057267   7.057267
#
#                           50%        75%        max
# HospitalAdmissions
# 0                   13.717653  27.506708  39.962029
# 1                   15.183071  27.644748  39.954129
# 2                   14.828338  27.317178  39.930003
# 3                   14.969666  27.243315  39.911736
# 4                   16.434666  28.879395  39.963434
# 5                   14.289030  27.290649  39.941888
# 6                   12.521193  25.446533  39.493403
# 7                   13.163932  23.729147  36.026420
# 8                   29.554798  33.031218  36.507639
# 12                   7.057267   7.057267   7.057267

# %%
df.groupby('CardiovascularCases')['Humidity'].describe()
# Out:
#                       count       mean        std        min        25%  \
# CardiovascularCases
# 0                      39.0  59.815203  28.312847  13.387338  33.656896
# 1                     210.0  58.799715  25.362149  10.008423  37.709986
# 2                     448.0  55.869382  25.717595  10.001506  33.578276
# 3                     813.0  55.008366  25.724456  10.130002  32.798740
# 4                    1062.0  54.232517  26.189122  10.055160  31.191641
# 5                    1033.0  54.930360  26.233848  10.181402  31.002433
# 6                     864.0  54.439666  26.318136  10.153345  32.714726
# 7                     577.0  53.198906  25.351909  10.199966  31.756132
# 8                     376.0  54.536237  26.429114  10.378533  30.580074
# 9                     208.0  54.887743  26.454211  10.314110  30.728599
# 10                    107.0  54.177124  25.524314  10.166856  33.858033
# 11                     47.0  57.652706  26.338795  10.800857  30.083286
# 12                     14.0  49.879407  23.572690  24.114349  32.636113
# 13                      7.0  61.381074  24.742456  32.598384  38.480989
# 14                      6.0  41.625688  21.995193  15.704943  22.729601
#
#                            50%        75%        max
# CardiovascularCases
# 0                    59.282633  88.375712  99.251896
# 1                    61.754924  80.831901  99.823281
# 2                    56.452241  78.582195  99.651608
# 3                    55.470956  75.790995  99.924140
# 4                    53.239160  77.965388  99.997493
# 5                    54.007128  77.816621  99.862632
# 6                    53.553226  77.364515  99.919898
# 7                    52.332016  75.791847  99.844399
# 8                    54.826805  77.694272  99.984138
# 9                    53.758881  77.849843  99.597950
# 10                   56.035608  76.424983  98.737179
# 11                   58.796018  80.652904  94.702566
# 12                   41.321113  68.224959  92.518826
# 13                   68.734795  80.517195  90.337970
# 14                   44.344823  55.670332  70.389512

# %%
df.groupby('CardiovascularCases')['Temperature'].describe()
# Out:
#                       count       mean        std       min        25%  \
# CardiovascularCases
# 0                      39.0  12.966757  15.095755 -9.874561   2.199099
# 1                     210.0  14.311303  15.098234 -9.931904   0.936677
# 2                     448.0  13.621728  14.144558 -9.831678   1.439173
# 3                     813.0  15.574336  14.693212 -9.920459   3.024186
# 4                    1062.0  15.181150  14.512804 -9.990998   2.684394
# 5                    1033.0  14.906088  14.042002 -9.967557   3.095408
# 6                     864.0  15.574094  14.461997 -9.938031   2.873309
# 7                     577.0  14.544999  14.514261 -9.970262   1.744720
# 8                     376.0  14.726398  15.019658 -9.911402   1.791931
# 9                     208.0  14.418346  15.205975 -9.955914   0.768340
# 10                    107.0  14.835866  13.445195 -9.188050   3.664193
# 11                     47.0  15.589898  14.000454 -9.708004   6.033509
# 12                     14.0  23.143845  12.480441 -3.858988  15.757701
# 13                      7.0  22.943354  16.859334 -8.359284  14.898177
# 14                      6.0   6.218135  12.053759 -7.459245  -2.658892
#
#                            50%        75%        max
# CardiovascularCases
# 0                     8.955095  24.945274  39.794395
# 1                    13.464228  28.207000  39.911736
# 2                    13.094057  25.442394  39.941888
# 3                    16.287230  28.403852  39.930003
# 4                    15.175481  27.965111  39.962029
# 5                    14.826298  26.616978  39.958937
# 6                    15.536240  27.617454  39.954129
# 7                    14.308615  26.677245  39.845950
# 8                    14.119931  28.492324  39.963434
# 9                    15.251319  27.393373  39.622222
# 10                   14.792155  25.538277  39.620609
# 11                   15.863714  27.470908  38.431228
# 12                   25.208005  34.251809  37.487267
# 13                   30.526657  35.489822  37.660104
# 14                    4.031327  17.181947  20.028876

# %%
df.shape
# Out:
# (5811, 15)

# %%
# Show a frequency table of HospitalAdmissions versus Humidity
df.groupby('HospitalAdmissions')['Humidity'].value_counts()
# Out:
# HospitalAdmissions  Humidity
# 0                   10.130002    1
#                     10.167705    1
#                     10.226827    1
#                     10.340716    1
#                     10.344293    1
#                                 ..
# 7                   98.573749    1
#                     99.057990    1
# 8                   54.875988    1
#                     64.874494    1
# 12                  81.251557    1
# Name: count, Length: 5811, dtype: int64

# %%
# Show a frequency table of HospitalAdmissions versus Temperature
df.groupby('HospitalAdmissions')['Temperature'].value_counts()
# Out:
# HospitalAdmissions  Temperature
# 0                   -9.911402      1
#                     -9.874561      1
#                     -9.849602      1
#                     -9.835854      1
#                     -9.831957      1
#                                   ..
# 7                    35.818860     1
#                      36.026420     1
# 8                    22.601957     1
#                      36.507639     1
# 12                   7.057267      1
# Name: count, Length: 5811, dtype: int64

# %%
df.groupby('CardiovascularCases')['Humidity'].value_counts()
# Out:
# CardiovascularCases  Humidity
# 0                    13.387338    1
#                      15.181794    1
#                      17.205555    1
#                      22.359056    1
#                      23.357292    1
#                                  ..
# 14                   18.077562    1
#                      36.685719    1
#                      52.003927    1
#                      56.892468    1
#                      70.389512    1
# Name: count, Length: 5811, dtype: int64

# %% [markdown]
# #### *Data Visualization*

# %%
# Use seaborn to create a histogram of HospitalAdmissions versus Temperature
seaborn.histplot(x='Temperature', data=df)
pyplot.show()
